# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('time_series_covid19_confirmed_global.csv')

data
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 269            NaN             Vietnam  14.058324  108.277199        0
# 270            NaN  West Bank and Gaza  31.952200   35.233200        0
# 271            NaN               Yemen  15.552727   48.516388        0
# 272            NaN              Zambia -13.133897   27.849332        0
# 273            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/20/21  2/21/21  \
# ...

# %%
data=data.groupby('Country/Region',as_index=False).sum()

data=data.drop(["Lat","Long"],axis=1)
data
# Out:
#          Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0           Afghanistan        0        0        0        0        0        0
# 1               Albania        0        0        0        0        0        0
# 2               Algeria        0        0        0        0        0        0
# 3               Andorra        0        0        0        0        0        0
# 4                Angola        0        0        0        0        0        0
# ..                  ...      ...      ...      ...      ...      ...      ...
# 187             Vietnam        0        2        2        2        2        2
# 188  West Bank and Gaza        0        0        0        0        0        0
# 189               Yemen        0        0        0        0        0        0
# 190              Zambia        0        0        0        0        0        0
# 191            Zimbabwe        0        0        0        0        0        0
#
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192 entries, 0 to 191
# Columns: 406 entries, Country/Region to 3/1/21
# dtypes: int64(405), object(1)
# memory usage: 610.5+ KB

# %%
d=data.T

d
# Out:
#                         0        1        2        3       4    \
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# ...                     ...      ...      ...      ...     ...
# 2/25/21               55680   104313   112622    10799   20695
# 2/26/21               55696   105229   112805    10822   20759
# 2/27/21               55707   106215   112960    10849   20782
# 2/28/21               55714   107167   113092    10866   20807
# 3/1/21                55733   107931   113255    10889   20854
#
#                                 5          6        7          8        9    \
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria
# ...

# %%
cases_confirmed = pd.DataFrame(columns=["Country","Date","Count"])
cases_confirmed
# Out:
# Empty DataFrame
# Columns: [Country, Date, Count]
# Index: []

# %%
data_colNames = data.drop(["Country/Region"],axis=1).columns
for i in range(len(data)):
    for j in range (len(data_colNames)):
        cases_confirmed =cases_confirmed.append({"Country":data["Country/Region"][i],"Date":data_colNames[j],"Count":d.loc[data_colNames[j]][i]},ignore_index=True)

# %%
cases_confirmed
# Out:
#            Country     Date  Count
# 0      Afghanistan  1/22/20      0
# 1      Afghanistan  1/23/20      0
# 2      Afghanistan  1/24/20      0
# 3      Afghanistan  1/25/20      0
# 4      Afghanistan  1/26/20      0
# ...            ...      ...    ...
# 77755     Zimbabwe  2/25/21  35994
# 77756     Zimbabwe  2/26/21  36044
# 77757     Zimbabwe  2/27/21  36058
# 77758     Zimbabwe  2/28/21  36089
# 77759     Zimbabwe   3/1/21  36115
#
# [77760 rows x 3 columns]

# %%
cases_confirmed["locID"] = np.nan
cases_confirmed["dateID"] = np.nan
cases_confirmed["caseID"] = np.nan #created new columns for forgein keys


cases_confirmed['Date']= cases_confirmed['Date'].astype('datetime64[ns]') #Makes the date column to date-time format

# %%
cases_confirmed= cases_confirmed[['Country','Date','locID','dateID','caseID','Count']] #modify order of columns (for V-lookup in excel)

# %%
cases_confirmed
# Out:
#            Country       Date  locID  dateID  caseID  Count
# 0      Afghanistan 2020-01-22    NaN     NaN     NaN      0
# 1      Afghanistan 2020-01-23    NaN     NaN     NaN      0
# 2      Afghanistan 2020-01-24    NaN     NaN     NaN      0
# 3      Afghanistan 2020-01-25    NaN     NaN     NaN      0
# 4      Afghanistan 2020-01-26    NaN     NaN     NaN      0
# ...            ...        ...    ...     ...     ...    ...
# 77755     Zimbabwe 2021-02-25    NaN     NaN     NaN  35994
# 77756     Zimbabwe 2021-02-26    NaN     NaN     NaN  36044
# 77757     Zimbabwe 2021-02-27    NaN     NaN     NaN  36058
# 77758     Zimbabwe 2021-02-28    NaN     NaN     NaN  36089
# 77759     Zimbabwe 2021-03-01    NaN     NaN     NaN  36115
#
# [77760 rows x 6 columns]

# %%
cases_confirmed.to_excel(r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\project1.0\Data\Fact tables\confirmedX.xlsx', index = False, header=False) #export as excel file for V-look up

# %%
cases_conf= pd.read_excel(r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\project1.0\Data\Fact tables\confirmedX.xlsx',header=None)



cases_conf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77760 entries, 0 to 77759
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       77760 non-null  object
#  1   1       77760 non-null  datetime64[ns]
#  2   2       72495 non-null  float64
#  3   3       77760 non-null  int64
#  4   4       77760 non-null  int64
#  5   5       77760 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 3.6+ MB

# %%
cases_conf[2] = cases_conf[2].values.astype(np.int64) #converts float value to int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77760 entries, 0 to 77759
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       77760 non-null  object
#  1   1       77760 non-null  datetime64[ns]
#  2   2       77760 non-null  int64
#  3   3       77760 non-null  int64
#  4   4       77760 non-null  int64
#  5   5       77760 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 3.6+ MB

# %%
cases_conf=cases_conf.drop([0,1],axis=1) #removes country name and date column

# %%
cases_conf.to_csv (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\project1.0\Data\Fact tables\fact_confirmed.csv', index = False, header=False) #### export as csv
